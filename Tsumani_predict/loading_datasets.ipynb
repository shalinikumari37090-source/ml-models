# %%
import pandas as pd

df = pd.read_csv("earthquake.csv")
df

# %%
df.dtypes
# Out:
# magnitude    float64
# cdi            int64
# mmi            int64
# sig            int64
# nst            int64
# dmin         float64
# gap          float64
# depth        float64
# latitude     float64
# longitude    float64
# Year           int64
# Month          int64
# tsunami        int64
# dtype: object

# %%
df.head()
# Out:
#    magnitude  cdi  mmi  sig  nst   dmin   gap    depth  latitude  longitude  \
# 0        7.0    8    7  768  117  0.509  17.0   14.000   -9.7963    159.596
# 1        6.9    4    4  735   99  2.229  34.0   25.000   -4.9559    100.738
# 2        7.0    3    3  755  147  3.125  18.0  579.000  -20.0508   -178.346
# 3        7.3    5    5  833  149  1.865  21.0   37.000  -19.2918   -172.129
# 4        6.6    0    2  670  131  4.998  27.0  624.464  -25.5948    178.278
#
#    Year  Month  tsunami
# 0  2022     11        1
# 1  2022     11        0
# 2  2022     11        1
# 3  2022     11        1
# 4  2022     11        1

# %%
df.tail()
# Out:
#      magnitude  cdi  mmi  sig  nst  dmin  gap  depth  latitude  longitude  \
# 777        7.7    0    8  912  427   0.0  0.0   60.0   13.0490    -88.660
# 778        6.9    5    7  745    0   0.0  0.0   36.4   56.7744   -153.281
# 779        7.1    0    7  776  372   0.0  0.0  103.0  -14.9280    167.170
# 780        6.8    0    5  711   64   0.0  0.0   33.0    6.6310    126.899
# 781        7.5    0    7  865  324   0.0  0.0   33.0    6.8980    126.579
#
#      Year  Month  tsunami
# 777  2001      1        0
# 778  2001      1        0
# 779  2001      1        0
# 780  2001      1        0
# 781  2001      1        0

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["magnitude"],df["latitude"])
plt.xlabel("Magnitude")
plt.ylabel("Latitude")
plt.title("Magnitude v/s Latitude")
# Out:
# Text(0.5, 1.0, 'Magnitude v/s Latitude')
